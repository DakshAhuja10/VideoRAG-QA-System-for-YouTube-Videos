# %%
import pandas as pd

# %%
file_1="video_with_meta_data_and_transcript.csv"

df=pd.read_csv(file_1)
df.head()
# Out:
#       video_id                                              title  length  \
# 0  wKw1tpN7NVE  Do Something Difficult Every Day | AMA #1 - As...   293.0
# 1  wKw1tpN7NVE  Do Something Difficult Every Day | AMA #1 - As...   293.0
# 2  wKw1tpN7NVE  Do Something Difficult Every Day | AMA #1 - As...   293.0
# 3  wKw1tpN7NVE  Do Something Difficult Every Day | AMA #1 - As...   293.0
# 4  wKw1tpN7NVE  Do Something Difficult Every Day | AMA #1 - As...   293.0
#
#    publish_date     views                                          url  \
# 0    20200219.0  147230.0  https://www.youtube.com/watch?v=wKw1tpN7NVE
# 1    20200219.0  147230.0  https://www.youtube.com/watch?v=wKw1tpN7NVE
# 2    20200219.0  147230.0  https://www.youtube.com/watch?v=wKw1tpN7NVE
# 3    20200219.0  147230.0  https://www.youtube.com/watch?v=wKw1tpN7NVE
# 4    20200219.0  147230.0  https://www.youtube.com/watch?v=wKw1tpN7NVE
#
#                                        text   start  duration
# ...

# %%
df.columns
# Out:
# Index(['video_id', 'title', 'length', 'publish_date', 'views', 'url', 'text',
#        'start', 'duration'],
#       dtype='object')

# %%
df2=pd.read_csv("videos.csv")

df2.head()
# Out:
#                                                Title  Length     video_id  \
# 0  Do Something Difficult Every Day | AMA #1 - As...   293.0  wKw1tpN7NVE
# 1                                                NaN     NaN          NaN
# 2                How to learn and master a new skill   578.0  _ySbzVXiwzQ
# 3                                                NaN     NaN          NaN
# 4  Make Disadvantage Your Superpower | Lex Fridma...   517.0  pXEl0R1BX-g
#
#    publish_date     views                                          url
# 0    20200219.0  147230.0  https://www.youtube.com/watch?v=wKw1tpN7NVE
# 1           NaN       NaN                                          NaN
# 2    20201121.0  807817.0  https://www.youtube.com/watch?v=_ySbzVXiwzQ
# 3           NaN       NaN                                          NaN
# 4    20200629.0  151610.0  https://www.youtube.com/watch?v=pXEl0R1BX-g

# %%
df2.columns
# Out:
# Index(['Title', 'Length', 'video_id', 'publish_date', 'views', 'url'], dtype='object')

# %%
from doc_loader import Csv_Loader

csv_path = "video_with_meta_data_and_transcript.csv"

loader = Csv_Loader(csv_path)
docs = loader.load()

print(len(docs))
print(docs[2])
# Out:
# 5008
# page_content='suffering is good for the soul where did' metadata={'video_id': 'wKw1tpN7NVE', 'title': 'Do Something Difficult Every Day | AMA #1 - Ask Me Anything with Lex Fridman', 'start': 6.629, 'duration': 5.821, 'url': 'https://www.youtube.com/watch?v=wKw1tpN7NVE', 'publish_date': 20200219.0, 'views': 147230.0, 'length': 293.0, 'citation_url': 'https://www.youtube.com/watch?v=wKw1tpN7NVE&t=6s'}

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from langchain_chroma import Chroma
#       2 from langchain_google_genai import GoogleGenerativeAIEmbeddings
#       4 embedder = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")
#
# ModuleNotFoundError: No module named 'langchain_chroma'
